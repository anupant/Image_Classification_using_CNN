# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 5
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 5:
# Samples: 10000
# Label Counts: {0: 1014, 1: 1014, 2: 952, 3: 1016, 4: 997, 5: 1025, 6: 980, 7: 977, 8: 1003, 9: 1022}
# First 20 Labels: [1, 8, 5, 1, 5, 7, 4, 3, 8, 2, 7, 2, 0, 1, 5, 9, 6, 2, 0, 8]
#
# Example of Image 5:
# Image - Min Value: 1 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 7 Name: horse

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    a = 0.
    b = 1.
    grayscale_min = 0.
    grayscale_max = 255.0
    return a + ( ( (x - grayscale_min)*(b - a) )/( grayscale_max - grayscale_min ) )
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn.preprocessing import LabelBinarizer
encoder = LabelBinarizer()
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    nb_classes = 10
    labels = np.array(x).reshape(-1)
    labels_one_hot = np.eye(nb_classes)[labels]
    return labels_one_hot
 
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, image_shape[0],image_shape[1], image_shape[2]],name ='x')
   


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,[None, n_classes],name ='y')
   
def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,name = 'keep_prob')
 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    #creating weights and bias using conv_ksize,conv_num_outputs and the shape of x_tensor
    
   
    input_dim_list = x_tensor.get_shape().as_list()
    input_depth = input_dim_list[3]
    
    weight = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1],input_depth, conv_num_outputs],stddev=0.1))
    
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    strides = [1,conv_strides[0],conv_strides[1],1]
    x = tf.nn.conv2d(x_tensor, weight,strides,padding='SAME') + bias
   
    filter_shape_pool = [1, pool_ksize[0], pool_ksize[1], 1]
    strides_pool = [1, pool_strides[0], pool_strides[1], 1]
    x = tf.nn.max_pool(x, filter_shape_pool ,strides_pool, padding='SAME')
    x = tf.nn.relu(x)
    return x
    

    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    y = tf.contrib.layers.flatten(x_tensor)
    return y


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    y = tf.contrib.layers.fully_connected(x_tensor,num_outputs)
    return y


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    return tf.contrib.layers.fully_connected(x_tensor,num_outputs,None)
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):

   # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
   #    Play around with different number of outputs, kernel size and stride
   # Function Definition from Above:
   ######################## LAYER 1 ##########################
   conv_strides = (2,2)
   conv_ksize = (3,3)
   
   pool_ksize = (2,2)
   pool_strides = (2,2)
   
   conv_num_outputs = 32
   x_tensor = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
   
   
   ######################## LAYER 2 ##########################
   conv_strides = (2,2)
   conv_ksize = (3,3)

   pool_ksize = (2,2)
   pool_strides = (2,2)
   
   conv_num_outputs = 64
   x_tensor = conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
   ######################## LAYER 3 ########################## 
   conv_num_outputs = 128 
   x_tensor = conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
 
   # TODO: Apply a Flatten Layer
   # Function Definition from Above:
   x_tensor = flatten(x_tensor)
   

   # TODO: Apply 1, 2, or 3 Fully Connected Layers
   #    Play around with different number of outputs
   # Function Definition from Above:
   
   fully_num_outputs = 1024
   x_tensor = fully_conn(x_tensor, fully_num_outputs)
   x_tensor = tf.nn.dropout(x_tensor, keep_prob)
   
 
   fully_num_outputs = 120
   x_tensor = fully_conn(x_tensor, fully_num_outputs)
   x_tensor = tf.nn.dropout(x_tensor, keep_prob)
 
   # TODO: Apply an Output Layer
   #    Set this to the number of classes
   # Function Definition from Above:
   
   output_num_outputs = 10
   x_tensor = output(x_tensor, output_num_outputs)

   
   # TODO: return output
   return x_tensor 

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: keep_probability})
   
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    
    cost = session.run(cost, feed_dict={x: feature_batch,y: label_batch, keep_prob: 1.})
    training_acc = session.run(accuracy, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.})
    valid_acc = session.run(accuracy, feed_dict={ x: valid_features,y: valid_labels,keep_prob: 1.})
    print('cost: {}'.format(cost))
    print('Training Accuracy: {}'.format(training_acc))
    print('validation accuracy: {}'.format(valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 60
batch_size = 128
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  cost: 2.1177430152893066
# Training Accuracy: 0.25
# validation accuracy: 0.305400013923645
# Epoch  2, CIFAR-10 Batch 1:  cost: 1.9322130680084229
# Training Accuracy: 0.44999998807907104
# validation accuracy: 0.38679999113082886
# Epoch  3, CIFAR-10 Batch 1:  cost: 1.7898585796356201
# Training Accuracy: 0.4749999940395355
# validation accuracy: 0.4153999984264374
# Epoch  4, CIFAR-10 Batch 1:  cost: 1.730699896812439
# Training Accuracy: 0.4749999940395355
# validation accuracy: 0.43380001187324524
# Epoch  5, CIFAR-10 Batch 1:  cost: 1.4762588739395142
# Training Accuracy: 0.6499999761581421
# validation accuracy: 0.47380000352859497
# Epoch  6, CIFAR-10 Batch 1:  cost: 1.362025499343872
# Training Accuracy: 0.6499999761581421
# validation accuracy: 0.47920000553131104
# Epoch  7, CIFAR-10 Batch 1:  cost: 1.303964376449585
# Training Accuracy: 0.625
# validation accuracy: 0.4851999878883362
# Epoch  8, CIFAR-10 Batch 1:  cost: 1.181618332862854
# Training Accuracy: 0.625
# validation accuracy: 0.5108000040054321
# Epoch  9, CIFAR-10 Batch 1:  cost: 1.0447969436645508
# Training Accuracy: 0.699999988079071
# validation accuracy: 0.5031999945640564
# Epoch 10, CIFAR-10 Batch 1:  cost: 0.920147716999054
# Training Accuracy: 0.675000011920929
# validation accuracy: 0.5248000025749207
# Epoch 11, CIFAR-10 Batch 1:  cost: 0.8787214159965515
# Training Accuracy: 0.7250000238418579
# validation accuracy: 0.5189999938011169
# Epoch 12, CIFAR-10 Batch 1:  cost: 0.8160949945449829
# Training Accuracy: 0.7250000238418579
# validation accuracy: 0.5130000114440918
# Epoch 13, CIFAR-10 Batch 1:  cost: 0.739140510559082
# Training Accuracy: 0.699999988079071
# validation accuracy: 0.51419997215271
# Epoch 14, CIFAR-10 Batch 1:  cost: 0.6773514151573181
# Training Accuracy: 0.75
# validation accuracy: 0.5267999768257141
# Epoch 15, CIFAR-10 Batch 1:  cost: 0.5988284349441528
# Training Accuracy: 0.800000011920929
# validation accuracy: 0.5231999754905701
# Epoch 16, CIFAR-10 Batch 1:  cost: 0.5786193013191223
# Training Accuracy: 0.7749999761581421
# validation accuracy: 0.5138000249862671
# Epoch 17, CIFAR-10 Batch 1:  cost: 0.5182963609695435
# Training Accuracy: 0.800000011920929
# validation accuracy: 0.5264000296592712
# Epoch 18, CIFAR-10 Batch 1:  cost: 0.47248587012290955
# Training Accuracy: 0.8500000238418579
# validation accuracy: 0.5166000127792358
# Epoch 19, CIFAR-10 Batch 1:  cost: 0.5114338994026184
# Training Accuracy: 0.824999988079071
# validation accuracy: 0.5026000142097473
# Epoch 20, CIFAR-10 Batch 1:  cost: 0.4608953595161438
# Training Accuracy: 0.875
# validation accuracy: 0.4973999857902527
# Epoch 21, CIFAR-10 Batch 1:  cost: 0.43919238448143005
# Training Accuracy: 0.800000011920929
# validation accuracy: 0.5127999782562256
# Epoch 22, CIFAR-10 Batch 1:  cost: 0.4052768349647522
# Training Accuracy: 0.8500000238418579
# validation accuracy: 0.5120000243186951
# Epoch 23, CIFAR-10 Batch 1:  cost: 0.3844338357448578
# Training Accuracy: 0.8500000238418579
# validation accuracy: 0.5206000208854675
# Epoch 24, CIFAR-10 Batch 1:  cost: 0.406424343585968
# Training Accuracy: 0.8500000238418579
# validation accuracy: 0.5008000135421753
# Epoch 25, CIFAR-10 Batch 1:  cost: 0.41501301527023315
# Training Accuracy: 0.8500000238418579
# validation accuracy: 0.515999972820282
# Epoch 26, CIFAR-10 Batch 1:  cost: 0.33581823110580444
# Training Accuracy: 0.875
# validation accuracy: 0.5224000215530396
# Epoch 27, CIFAR-10 Batch 1:  cost: 0.3352455496788025
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.5094000101089478
# Epoch 28, CIFAR-10 Batch 1:  cost: 0.30309778451919556
# Training Accuracy: 0.875
# validation accuracy: 0.4991999864578247
# Epoch 29, CIFAR-10 Batch 1:  cost: 0.2932341694831848
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.5019999742507935
# Epoch 30, CIFAR-10 Batch 1:  cost: 0.31207355856895447
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.5108000040054321
# Epoch 31, CIFAR-10 Batch 1:  cost: 0.29584354162216187
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.4997999966144562
# Epoch 32, CIFAR-10 Batch 1:  cost: 0.1892859935760498
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.5184000134468079
# Epoch 33, CIFAR-10 Batch 1:  cost: 0.15053105354309082
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.510200023651123
# Epoch 34, CIFAR-10 Batch 1:  cost: 0.1498246043920517
# Training Accuracy: 1.0
# validation accuracy: 0.5070000290870667
# Epoch 35, CIFAR-10 Batch 1:  cost: 0.16805893182754517
# Training Accuracy: 1.0
# validation accuracy: 0.49779999256134033
# Epoch 36, CIFAR-10 Batch 1:  cost: 0.180770143866539
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.4812000095844269
# Epoch 37, CIFAR-10 Batch 1:  cost: 0.2010848969221115
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.48019999265670776
# Epoch 38, CIFAR-10 Batch 1:  cost: 0.15365199744701385
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.4912000000476837
# Epoch 39, CIFAR-10 Batch 1:  cost: 0.15472927689552307
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.48539999127388
# Epoch 40, CIFAR-10 Batch 1:  cost: 0.1289229840040207
# Training Accuracy: 1.0
# validation accuracy: 0.48840001225471497
# Epoch 41, CIFAR-10 Batch 1:  cost: 0.14264334738254547
# Training Accuracy: 1.0
# validation accuracy: 0.5072000026702881
# Epoch 42, CIFAR-10 Batch 1:  cost: 0.1347695142030716
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.5031999945640564
# Epoch 43, CIFAR-10 Batch 1:  cost: 0.09977681934833527
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.5013999938964844
# Epoch 44, CIFAR-10 Batch 1:  cost: 0.07871198654174805
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.5210000276565552
# Epoch 45, CIFAR-10 Batch 1:  cost: 0.07471077889204025
# Training Accuracy: 1.0
# validation accuracy: 0.5072000026702881
# Epoch 46, CIFAR-10 Batch 1:  cost: 0.05824166536331177
# Training Accuracy: 1.0
# validation accuracy: 0.5001999735832214
# Epoch 47, CIFAR-10 Batch 1:  cost: 0.06253969669342041
# Training Accuracy: 1.0
# validation accuracy: 0.5103999972343445
# Epoch 48, CIFAR-10 Batch 1:  cost: 0.04929792508482933
# Training Accuracy: 1.0
# validation accuracy: 0.5098000168800354
# Epoch 49, CIFAR-10 Batch 1:  cost: 0.055129148066043854
# Training Accuracy: 1.0
# validation accuracy: 0.5081999897956848
# Epoch 50, CIFAR-10 Batch 1:  cost: 0.04841999337077141
# Training Accuracy: 1.0
# validation accuracy: 0.49480000138282776
# Epoch 51, CIFAR-10 Batch 1:  cost: 0.05481374263763428
# Training Accuracy: 1.0
# validation accuracy: 0.49320000410079956
# Epoch 52, CIFAR-10 Batch 1:  cost: 0.13275711238384247
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.4805999994277954
# Epoch 53, CIFAR-10 Batch 1:  cost: 0.048363879323005676
# Training Accuracy: 1.0
# validation accuracy: 0.49480000138282776
# Epoch 54, CIFAR-10 Batch 1:  cost: 0.03461023420095444
# Training Accuracy: 1.0
# validation accuracy: 0.48899999260902405
# Epoch 55, CIFAR-10 Batch 1:  cost: 0.04539766162633896
# Training Accuracy: 1.0
# validation accuracy: 0.47519999742507935
# Epoch 56, CIFAR-10 Batch 1:  cost: 0.04077260568737984
# Training Accuracy: 1.0
# validation accuracy: 0.49480000138282776
# Epoch 57, CIFAR-10 Batch 1:  cost: 0.019068025052547455
# Training Accuracy: 1.0
# validation accuracy: 0.506600022315979
# Epoch 58, CIFAR-10 Batch 1:  cost: 0.020151343196630478
# Training Accuracy: 1.0
# validation accuracy: 0.4912000000476837
# Epoch 59, CIFAR-10 Batch 1:  cost: 0.033465512096881866
# Training Accuracy: 1.0
# validation accuracy: 0.5022000074386597
# Epoch 60, CIFAR-10 Batch 1:  cost: 0.020359236747026443
# Training Accuracy: 1.0
# validation accuracy: 0.5040000081062317

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  cost: 2.127894878387451
# Training Accuracy: 0.22499999403953552
# validation accuracy: 0.28760001063346863
# Epoch  1, CIFAR-10 Batch 2:  cost: 1.695360541343689
# Training Accuracy: 0.42500001192092896
# validation accuracy: 0.36340001225471497
# Epoch  1, CIFAR-10 Batch 3:  cost: 1.512512445449829
# Training Accuracy: 0.5249999761581421
# validation accuracy: 0.3646000027656555
# Epoch  1, CIFAR-10 Batch 4:  cost: 1.5112723112106323
# Training Accuracy: 0.4000000059604645
# validation accuracy: 0.4115999937057495
# Epoch  1, CIFAR-10 Batch 5:  cost: 1.6285938024520874
# Training Accuracy: 0.4000000059604645
# validation accuracy: 0.448199987411499
# Epoch  2, CIFAR-10 Batch 1:  cost: 1.6588958501815796
# Training Accuracy: 0.4749999940395355
# validation accuracy: 0.453000009059906
# Epoch  2, CIFAR-10 Batch 2:  cost: 1.4620078802108765
# Training Accuracy: 0.4749999940395355
# validation accuracy: 0.4564000070095062
# Epoch  2, CIFAR-10 Batch 3:  cost: 1.1635886430740356
# Training Accuracy: 0.6000000238418579
# validation accuracy: 0.4706000089645386
# Epoch  2, CIFAR-10 Batch 4:  cost: 1.2739194631576538
# Training Accuracy: 0.5249999761581421
# validation accuracy: 0.5062000155448914
# Epoch  2, CIFAR-10 Batch 5:  cost: 1.469808578491211
# Training Accuracy: 0.4749999940395355
# validation accuracy: 0.5062000155448914
# Epoch  3, CIFAR-10 Batch 1:  cost: 1.3655822277069092
# Training Accuracy: 0.574999988079071
# validation accuracy: 0.5138000249862671
# Epoch  3, CIFAR-10 Batch 2:  cost: 1.1509029865264893
# Training Accuracy: 0.625
# validation accuracy: 0.4966000020503998
# Epoch  3, CIFAR-10 Batch 3:  cost: 1.0153604745864868
# Training Accuracy: 0.699999988079071
# validation accuracy: 0.4968000054359436
# Epoch  3, CIFAR-10 Batch 4:  cost: 1.1399965286254883
# Training Accuracy: 0.6000000238418579
# validation accuracy: 0.5246000289916992
# Epoch  3, CIFAR-10 Batch 5:  cost: 1.2678794860839844
# Training Accuracy: 0.44999998807907104
# validation accuracy: 0.5338000059127808
# Epoch  4, CIFAR-10 Batch 1:  cost: 1.1750866174697876
# Training Accuracy: 0.625
# validation accuracy: 0.5284000039100647
# Epoch  4, CIFAR-10 Batch 2:  cost: 1.0696415901184082
# Training Accuracy: 0.6000000238418579
# validation accuracy: 0.5437999963760376
# Epoch  4, CIFAR-10 Batch 3:  cost: 0.8873873949050903
# Training Accuracy: 0.699999988079071
# validation accuracy: 0.5386000275611877
# Epoch  4, CIFAR-10 Batch 4:  cost: 0.9945939779281616
# Training Accuracy: 0.6499999761581421
# validation accuracy: 0.5537999868392944
# Epoch  4, CIFAR-10 Batch 5:  cost: 1.1078466176986694
# Training Accuracy: 0.574999988079071
# validation accuracy: 0.5586000084877014
# Epoch  5, CIFAR-10 Batch 1:  cost: 1.1198561191558838
# Training Accuracy: 0.6499999761581421
# validation accuracy: 0.5406000018119812
# Epoch  5, CIFAR-10 Batch 2:  cost: 1.0272142887115479
# Training Accuracy: 0.6499999761581421
# validation accuracy: 0.5565999746322632
# Epoch  5, CIFAR-10 Batch 3:  cost: 0.8575451970100403
# Training Accuracy: 0.699999988079071
# validation accuracy: 0.5540000200271606
# Epoch  5, CIFAR-10 Batch 4:  cost: 0.9024235010147095
# Training Accuracy: 0.6499999761581421
# validation accuracy: 0.5600000023841858
# Epoch  5, CIFAR-10 Batch 5:  cost: 1.0206587314605713
# Training Accuracy: 0.625
# validation accuracy: 0.5735999941825867
# Epoch  6, CIFAR-10 Batch 1:  cost: 0.9997711181640625
# Training Accuracy: 0.699999988079071
# validation accuracy: 0.5540000200271606
# Epoch  6, CIFAR-10 Batch 2:  cost: 0.9886374473571777
# Training Accuracy: 0.6000000238418579
# validation accuracy: 0.5781999826431274
# Epoch  6, CIFAR-10 Batch 3:  cost: 0.8153789639472961
# Training Accuracy: 0.7749999761581421
# validation accuracy: 0.5830000042915344
# Epoch  6, CIFAR-10 Batch 4:  cost: 0.8313195109367371
# Training Accuracy: 0.7250000238418579
# validation accuracy: 0.5777999758720398
# Epoch  6, CIFAR-10 Batch 5:  cost: 0.9110710024833679
# Training Accuracy: 0.6499999761581421
# validation accuracy: 0.5867999792098999
# Epoch  7, CIFAR-10 Batch 1:  cost: 0.948540210723877
# Training Accuracy: 0.675000011920929
# validation accuracy: 0.5748000144958496
# Epoch  7, CIFAR-10 Batch 2:  cost: 0.9019721746444702
# Training Accuracy: 0.6499999761581421
# validation accuracy: 0.5774000287055969
# Epoch  7, CIFAR-10 Batch 3:  cost: 0.7307808995246887
# Training Accuracy: 0.824999988079071
# validation accuracy: 0.5809999704360962
# Epoch  7, CIFAR-10 Batch 4:  cost: 0.8041287660598755
# Training Accuracy: 0.7250000238418579
# validation accuracy: 0.5902000069618225
# Epoch  7, CIFAR-10 Batch 5:  cost: 0.8542359471321106
# Training Accuracy: 0.699999988079071
# validation accuracy: 0.5902000069618225
# Epoch  8, CIFAR-10 Batch 1:  cost: 0.8083478808403015
# Training Accuracy: 0.6499999761581421
# validation accuracy: 0.574999988079071
# Epoch  8, CIFAR-10 Batch 2:  cost: 0.8508175015449524
# Training Accuracy: 0.699999988079071
# validation accuracy: 0.592199981212616
# Epoch  8, CIFAR-10 Batch 3:  cost: 0.6892581582069397
# Training Accuracy: 0.75
# validation accuracy: 0.5799999833106995
# Epoch  8, CIFAR-10 Batch 4:  cost: 0.7186509370803833
# Training Accuracy: 0.75
# validation accuracy: 0.5953999757766724
# Epoch  8, CIFAR-10 Batch 5:  cost: 0.7364814281463623
# Training Accuracy: 0.75
# validation accuracy: 0.5917999744415283
# Epoch  9, CIFAR-10 Batch 1:  cost: 0.7184021472930908
# Training Accuracy: 0.7250000238418579
# validation accuracy: 0.5839999914169312
# Epoch  9, CIFAR-10 Batch 2:  cost: 0.7999698519706726
# Training Accuracy: 0.675000011920929
# validation accuracy: 0.59579998254776
# Epoch  9, CIFAR-10 Batch 3:  cost: 0.6356239318847656
# Training Accuracy: 0.800000011920929
# validation accuracy: 0.5898000001907349
# Epoch  9, CIFAR-10 Batch 4:  cost: 0.6990607380867004
# Training Accuracy: 0.7250000238418579
# validation accuracy: 0.6015999913215637
# Epoch  9, CIFAR-10 Batch 5:  cost: 0.7120042443275452
# Training Accuracy: 0.75
# validation accuracy: 0.5906000137329102
# Epoch 10, CIFAR-10 Batch 1:  cost: 0.6523046493530273
# Training Accuracy: 0.75
# validation accuracy: 0.6001999974250793
# Epoch 10, CIFAR-10 Batch 2:  cost: 0.7900351881980896
# Training Accuracy: 0.625
# validation accuracy: 0.5848000049591064
# Epoch 10, CIFAR-10 Batch 3:  cost: 0.6046042442321777
# Training Accuracy: 0.7250000238418579
# validation accuracy: 0.5861999988555908
# Epoch 10, CIFAR-10 Batch 4:  cost: 0.6303848028182983
# Training Accuracy: 0.75
# validation accuracy: 0.6065999865531921
# Epoch 10, CIFAR-10 Batch 5:  cost: 0.6535592079162598
# Training Accuracy: 0.8500000238418579
# validation accuracy: 0.5892000198364258
# Epoch 11, CIFAR-10 Batch 1:  cost: 0.6356164216995239
# Training Accuracy: 0.75
# validation accuracy: 0.5996000170707703
# Epoch 11, CIFAR-10 Batch 2:  cost: 0.6787358522415161
# Training Accuracy: 0.75
# validation accuracy: 0.5992000102996826
# Epoch 11, CIFAR-10 Batch 3:  cost: 0.5983826518058777
# Training Accuracy: 0.699999988079071
# validation accuracy: 0.5871999859809875
# Epoch 11, CIFAR-10 Batch 4:  cost: 0.5807744264602661
# Training Accuracy: 0.824999988079071
# validation accuracy: 0.6065999865531921
# Epoch 11, CIFAR-10 Batch 5:  cost: 0.6887636780738831
# Training Accuracy: 0.75
# validation accuracy: 0.5630000233650208
# Epoch 12, CIFAR-10 Batch 1:  cost: 0.6279258131980896
# Training Accuracy: 0.7749999761581421
# validation accuracy: 0.5834000110626221
# Epoch 12, CIFAR-10 Batch 2:  cost: 0.6720700263977051
# Training Accuracy: 0.824999988079071
# validation accuracy: 0.5916000008583069
# Epoch 12, CIFAR-10 Batch 3:  cost: 0.534235954284668
# Training Accuracy: 0.7749999761581421
# validation accuracy: 0.5849999785423279
# Epoch 12, CIFAR-10 Batch 4:  cost: 0.5530047416687012
# Training Accuracy: 0.7749999761581421
# validation accuracy: 0.6123999953269958
# Epoch 12, CIFAR-10 Batch 5:  cost: 0.610701858997345
# Training Accuracy: 0.824999988079071
# validation accuracy: 0.5856000185012817
# Epoch 13, CIFAR-10 Batch 1:  cost: 0.6673911213874817
# Training Accuracy: 0.7749999761581421
# validation accuracy: 0.574999988079071
# Epoch 13, CIFAR-10 Batch 2:  cost: 0.6034526824951172
# Training Accuracy: 0.800000011920929
# validation accuracy: 0.5892000198364258
# Epoch 13, CIFAR-10 Batch 3:  cost: 0.5004640817642212
# Training Accuracy: 0.800000011920929
# validation accuracy: 0.590399980545044
# Epoch 13, CIFAR-10 Batch 4:  cost: 0.44885969161987305
# Training Accuracy: 0.875
# validation accuracy: 0.6093999743461609
# Epoch 13, CIFAR-10 Batch 5:  cost: 0.5356429815292358
# Training Accuracy: 0.8500000238418579
# validation accuracy: 0.5971999764442444
# Epoch 14, CIFAR-10 Batch 1:  cost: 0.5193617343902588
# Training Accuracy: 0.7749999761581421
# validation accuracy: 0.6064000129699707
# Epoch 14, CIFAR-10 Batch 2:  cost: 0.5574740767478943
# Training Accuracy: 0.824999988079071
# validation accuracy: 0.6015999913215637
# Epoch 14, CIFAR-10 Batch 3:  cost: 0.4569431245326996
# Training Accuracy: 0.800000011920929
# validation accuracy: 0.6061999797821045
# Epoch 14, CIFAR-10 Batch 4:  cost: 0.44069018959999084
# Training Accuracy: 0.875
# validation accuracy: 0.6101999878883362
# Epoch 14, CIFAR-10 Batch 5:  cost: 0.5464873313903809
# Training Accuracy: 0.800000011920929
# validation accuracy: 0.5881999731063843
# Epoch 15, CIFAR-10 Batch 1:  cost: 0.47829169034957886
# Training Accuracy: 0.800000011920929
# validation accuracy: 0.6092000007629395
# Epoch 15, CIFAR-10 Batch 2:  cost: 0.539258599281311
# Training Accuracy: 0.8500000238418579
# validation accuracy: 0.5946000218391418
# Epoch 15, CIFAR-10 Batch 3:  cost: 0.4398694634437561
# Training Accuracy: 0.824999988079071
# validation accuracy: 0.6025999784469604
# Epoch 15, CIFAR-10 Batch 4:  cost: 0.4409632086753845
# Training Accuracy: 0.875
# validation accuracy: 0.6118000149726868
# Epoch 15, CIFAR-10 Batch 5:  cost: 0.5371658205986023
# Training Accuracy: 0.800000011920929
# validation accuracy: 0.6114000082015991
# Epoch 16, CIFAR-10 Batch 1:  cost: 0.4560956060886383
# Training Accuracy: 0.824999988079071
# validation accuracy: 0.6140000224113464
# Epoch 16, CIFAR-10 Batch 2:  cost: 0.4544086456298828
# Training Accuracy: 0.875
# validation accuracy: 0.6151999831199646
# Epoch 16, CIFAR-10 Batch 3:  cost: 0.3974744379520416
# Training Accuracy: 0.824999988079071
# validation accuracy: 0.6101999878883362
# Epoch 16, CIFAR-10 Batch 4:  cost: 0.4109319746494293
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.6018000245094299
# Epoch 16, CIFAR-10 Batch 5:  cost: 0.4663359522819519
# Training Accuracy: 0.8500000238418579
# validation accuracy: 0.6075999736785889
# Epoch 17, CIFAR-10 Batch 1:  cost: 0.4401451647281647
# Training Accuracy: 0.875
# validation accuracy: 0.616599977016449
# Epoch 17, CIFAR-10 Batch 2:  cost: 0.4496461749076843
# Training Accuracy: 0.8500000238418579
# validation accuracy: 0.6078000068664551
# Epoch 17, CIFAR-10 Batch 3:  cost: 0.39618849754333496
# Training Accuracy: 0.824999988079071
# validation accuracy: 0.6082000136375427
# Epoch 17, CIFAR-10 Batch 4:  cost: 0.4366087019443512
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6122000217437744
# Epoch 17, CIFAR-10 Batch 5:  cost: 0.3645424246788025
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.6150000095367432
# Epoch 18, CIFAR-10 Batch 1:  cost: 0.4330321252346039
# Training Accuracy: 0.824999988079071
# validation accuracy: 0.621399998664856
# Epoch 18, CIFAR-10 Batch 2:  cost: 0.43257197737693787
# Training Accuracy: 0.875
# validation accuracy: 0.6101999878883362
# Epoch 18, CIFAR-10 Batch 3:  cost: 0.31606146693229675
# Training Accuracy: 0.8999999761581421
# validation accuracy: 0.6007999777793884
# Epoch 18, CIFAR-10 Batch 4:  cost: 0.43206754326820374
# Training Accuracy: 0.875
# validation accuracy: 0.5929999947547913
# Epoch 18, CIFAR-10 Batch 5:  cost: 0.3763349950313568
# Training Accuracy: 0.8500000238418579
# validation accuracy: 0.6092000007629395
# Epoch 19, CIFAR-10 Batch 1:  cost: 0.38010373711586
# Training Accuracy: 0.8500000238418579
# validation accuracy: 0.6195999979972839
# Epoch 19, CIFAR-10 Batch 2:  cost: 0.4407290518283844
# Training Accuracy: 0.8500000238418579
# validation accuracy: 0.6168000102043152
# Epoch 19, CIFAR-10 Batch 3:  cost: 0.2928636074066162
# Training Accuracy: 0.8999999761581421
# validation accuracy: 0.600600004196167
# Epoch 19, CIFAR-10 Batch 4:  cost: 0.4184439778327942
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6025999784469604
# Epoch 19, CIFAR-10 Batch 5:  cost: 0.31880372762680054
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6100000143051147
# Epoch 20, CIFAR-10 Batch 1:  cost: 0.4275835156440735
# Training Accuracy: 0.824999988079071
# validation accuracy: 0.6269999742507935
# Epoch 20, CIFAR-10 Batch 2:  cost: 0.40868353843688965
# Training Accuracy: 0.875
# validation accuracy: 0.604200005531311
# Epoch 20, CIFAR-10 Batch 3:  cost: 0.2793687880039215
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.6043999791145325
# Epoch 20, CIFAR-10 Batch 4:  cost: 0.39614051580429077
# Training Accuracy: 0.8999999761581421
# validation accuracy: 0.6050000190734863
# Epoch 20, CIFAR-10 Batch 5:  cost: 0.2840438187122345
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6055999994277954
# Epoch 21, CIFAR-10 Batch 1:  cost: 0.42786353826522827
# Training Accuracy: 0.7749999761581421
# validation accuracy: 0.6251999735832214
# Epoch 21, CIFAR-10 Batch 2:  cost: 0.39133840799331665
# Training Accuracy: 0.824999988079071
# validation accuracy: 0.6069999933242798
# Epoch 21, CIFAR-10 Batch 3:  cost: 0.2647895812988281
# Training Accuracy: 0.8999999761581421
# validation accuracy: 0.6025999784469604
# Epoch 21, CIFAR-10 Batch 4:  cost: 0.33724451065063477
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6096000075340271
# Epoch 21, CIFAR-10 Batch 5:  cost: 0.2955138087272644
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6159999966621399
# Epoch 22, CIFAR-10 Batch 1:  cost: 0.386319100856781
# Training Accuracy: 0.8999999761581421
# validation accuracy: 0.6161999702453613
# Epoch 22, CIFAR-10 Batch 2:  cost: 0.3573637306690216
# Training Accuracy: 0.875
# validation accuracy: 0.6195999979972839
# Epoch 22, CIFAR-10 Batch 3:  cost: 0.2517709732055664
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.5902000069618225
# Epoch 22, CIFAR-10 Batch 4:  cost: 0.352655291557312
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.609000027179718
# Epoch 22, CIFAR-10 Batch 5:  cost: 0.2530212998390198
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6191999912261963
# Epoch 23, CIFAR-10 Batch 1:  cost: 0.3521508574485779
# Training Accuracy: 0.8999999761581421
# validation accuracy: 0.6159999966621399
# Epoch 23, CIFAR-10 Batch 2:  cost: 0.35551100969314575
# Training Accuracy: 0.8999999761581421
# validation accuracy: 0.6032000184059143
# Epoch 23, CIFAR-10 Batch 3:  cost: 0.2134559154510498
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.6029999852180481
# Epoch 23, CIFAR-10 Batch 4:  cost: 0.30103665590286255
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6118000149726868
# Epoch 23, CIFAR-10 Batch 5:  cost: 0.3095007836818695
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6304000020027161
# Epoch 24, CIFAR-10 Batch 1:  cost: 0.36031579971313477
# Training Accuracy: 0.875
# validation accuracy: 0.6215999722480774
# Epoch 24, CIFAR-10 Batch 2:  cost: 0.3542655110359192
# Training Accuracy: 0.8999999761581421
# validation accuracy: 0.6240000128746033
# Epoch 24, CIFAR-10 Batch 3:  cost: 0.225432351231575
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.5979999899864197
# Epoch 24, CIFAR-10 Batch 4:  cost: 0.27370685338974
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6240000128746033
# Epoch 24, CIFAR-10 Batch 5:  cost: 0.23825320601463318
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6137999892234802
# Epoch 25, CIFAR-10 Batch 1:  cost: 0.3493095934391022
# Training Accuracy: 0.875
# validation accuracy: 0.6086000204086304
# Epoch 25, CIFAR-10 Batch 2:  cost: 0.3270259499549866
# Training Accuracy: 0.8999999761581421
# validation accuracy: 0.6222000122070312
# Epoch 25, CIFAR-10 Batch 3:  cost: 0.20146164298057556
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.5929999947547913
# Epoch 25, CIFAR-10 Batch 4:  cost: 0.28363117575645447
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6191999912261963
# Epoch 25, CIFAR-10 Batch 5:  cost: 0.2160518616437912
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6273999810218811
# Epoch 26, CIFAR-10 Batch 1:  cost: 0.32110539078712463
# Training Accuracy: 0.8999999761581421
# validation accuracy: 0.6075999736785889
# Epoch 26, CIFAR-10 Batch 2:  cost: 0.34625178575515747
# Training Accuracy: 0.8999999761581421
# validation accuracy: 0.628600001335144
# Epoch 26, CIFAR-10 Batch 3:  cost: 0.19605524837970734
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.5898000001907349
# Epoch 26, CIFAR-10 Batch 4:  cost: 0.22311954200267792
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6323999762535095
# Epoch 26, CIFAR-10 Batch 5:  cost: 0.20358379185199738
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6287999749183655
# Epoch 27, CIFAR-10 Batch 1:  cost: 0.3030652105808258
# Training Accuracy: 0.8999999761581421
# validation accuracy: 0.6065999865531921
# Epoch 27, CIFAR-10 Batch 2:  cost: 0.3313663601875305
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.6097999811172485
# Epoch 27, CIFAR-10 Batch 3:  cost: 0.22601084411144257
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.600600004196167
# Epoch 27, CIFAR-10 Batch 4:  cost: 0.2063637226819992
# Training Accuracy: 1.0
# validation accuracy: 0.6341999769210815
# Epoch 27, CIFAR-10 Batch 5:  cost: 0.1771102398633957
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6345999836921692
# Epoch 28, CIFAR-10 Batch 1:  cost: 0.24430310726165771
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.6158000230789185
# Epoch 28, CIFAR-10 Batch 2:  cost: 0.29151374101638794
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.6317999958992004
# Epoch 28, CIFAR-10 Batch 3:  cost: 0.16557089984416962
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.614799976348877
# Epoch 28, CIFAR-10 Batch 4:  cost: 0.20612628757953644
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6323999762535095
# Epoch 28, CIFAR-10 Batch 5:  cost: 0.1998794972896576
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6273999810218811
# Epoch 29, CIFAR-10 Batch 1:  cost: 0.2411908209323883
# Training Accuracy: 0.8999999761581421
# validation accuracy: 0.6284000277519226
# Epoch 29, CIFAR-10 Batch 2:  cost: 0.3407328128814697
# Training Accuracy: 0.8999999761581421
# validation accuracy: 0.6340000033378601
# Epoch 29, CIFAR-10 Batch 3:  cost: 0.16564147174358368
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.597599983215332
# Epoch 29, CIFAR-10 Batch 4:  cost: 0.22895535826683044
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6200000047683716
# Epoch 29, CIFAR-10 Batch 5:  cost: 0.17392253875732422
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6276000142097473
# Epoch 30, CIFAR-10 Batch 1:  cost: 0.226067453622818
# Training Accuracy: 0.8999999761581421
# validation accuracy: 0.629800021648407
# Epoch 30, CIFAR-10 Batch 2:  cost: 0.33419933915138245
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.6359999775886536
# Epoch 30, CIFAR-10 Batch 3:  cost: 0.17994703352451324
# Training Accuracy: 1.0
# validation accuracy: 0.6010000109672546
# Epoch 30, CIFAR-10 Batch 4:  cost: 0.20399799942970276
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6284000277519226
# Epoch 30, CIFAR-10 Batch 5:  cost: 0.15960729122161865
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6335999965667725
# Epoch 31, CIFAR-10 Batch 1:  cost: 0.2519990801811218
# Training Accuracy: 0.8999999761581421
# validation accuracy: 0.626800000667572
# Epoch 31, CIFAR-10 Batch 2:  cost: 0.26332640647888184
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.6308000087738037
# Epoch 31, CIFAR-10 Batch 3:  cost: 0.14730259776115417
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6155999898910522
# Epoch 31, CIFAR-10 Batch 4:  cost: 0.19805696606636047
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6236000061035156
# Epoch 31, CIFAR-10 Batch 5:  cost: 0.1603444218635559
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6388000249862671
# Epoch 32, CIFAR-10 Batch 1:  cost: 0.25563064217567444
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.6182000041007996
# Epoch 32, CIFAR-10 Batch 2:  cost: 0.25181061029434204
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6177999973297119
# Epoch 32, CIFAR-10 Batch 3:  cost: 0.1402333527803421
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6003999710083008
# Epoch 32, CIFAR-10 Batch 4:  cost: 0.21135106682777405
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.626800000667572
# Epoch 32, CIFAR-10 Batch 5:  cost: 0.14454931020736694
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6290000081062317
# Epoch 33, CIFAR-10 Batch 1:  cost: 0.18628588318824768
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6262000203132629
# Epoch 33, CIFAR-10 Batch 2:  cost: 0.2409156858921051
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6327999830245972
# Epoch 33, CIFAR-10 Batch 3:  cost: 0.15306994318962097
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.5968000292778015
# Epoch 33, CIFAR-10 Batch 4:  cost: 0.17007529735565186
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.621399998664856
# Epoch 33, CIFAR-10 Batch 5:  cost: 0.15539012849330902
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6330000162124634
# Epoch 34, CIFAR-10 Batch 1:  cost: 0.20945100486278534
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6244000196456909
# Epoch 34, CIFAR-10 Batch 2:  cost: 0.24408988654613495
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6172000169754028
# Epoch 34, CIFAR-10 Batch 3:  cost: 0.14531853795051575
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6118000149726868
# Epoch 34, CIFAR-10 Batch 4:  cost: 0.15379948914051056
# Training Accuracy: 1.0
# validation accuracy: 0.6240000128746033
# Epoch 34, CIFAR-10 Batch 5:  cost: 0.11984473466873169
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6330000162124634
# Epoch 35, CIFAR-10 Batch 1:  cost: 0.167038232088089
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6312000155448914
# Epoch 35, CIFAR-10 Batch 2:  cost: 0.2165701687335968
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6295999884605408
# Epoch 35, CIFAR-10 Batch 3:  cost: 0.17205466330051422
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6086000204086304
# Epoch 35, CIFAR-10 Batch 4:  cost: 0.14533033967018127
# Training Accuracy: 1.0
# validation accuracy: 0.6255999803543091
# Epoch 35, CIFAR-10 Batch 5:  cost: 0.14478325843811035
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6381999850273132
# Epoch 36, CIFAR-10 Batch 1:  cost: 0.2203865349292755
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.6251999735832214
# Epoch 36, CIFAR-10 Batch 2:  cost: 0.2213226854801178
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6262000203132629
# Epoch 36, CIFAR-10 Batch 3:  cost: 0.12087702751159668
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6177999973297119
# Epoch 36, CIFAR-10 Batch 4:  cost: 0.15171940624713898
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6269999742507935
# Epoch 36, CIFAR-10 Batch 5:  cost: 0.10802419483661652
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6398000121116638
# Epoch 37, CIFAR-10 Batch 1:  cost: 0.1872008889913559
# Training Accuracy: 1.0
# validation accuracy: 0.6195999979972839
# Epoch 37, CIFAR-10 Batch 2:  cost: 0.2334165871143341
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.6236000061035156
# Epoch 37, CIFAR-10 Batch 3:  cost: 0.10750943422317505
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6273999810218811
# Epoch 37, CIFAR-10 Batch 4:  cost: 0.15019354224205017
# Training Accuracy: 1.0
# validation accuracy: 0.6262000203132629
# Epoch 37, CIFAR-10 Batch 5:  cost: 0.10769462585449219
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6413999795913696
# Epoch 38, CIFAR-10 Batch 1:  cost: 0.1841554045677185
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.6359999775886536
# Epoch 38, CIFAR-10 Batch 2:  cost: 0.1887265294790268
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6284000277519226
# Epoch 38, CIFAR-10 Batch 3:  cost: 0.0966649204492569
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6141999959945679
# Epoch 38, CIFAR-10 Batch 4:  cost: 0.11790087074041367
# Training Accuracy: 1.0
# validation accuracy: 0.6259999871253967
# Epoch 38, CIFAR-10 Batch 5:  cost: 0.10839080810546875
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6349999904632568
# Epoch 39, CIFAR-10 Batch 1:  cost: 0.18265774846076965
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6161999702453613
# Epoch 39, CIFAR-10 Batch 2:  cost: 0.18245714902877808
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.6177999973297119
# Epoch 39, CIFAR-10 Batch 3:  cost: 0.09528298676013947
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6057999730110168
# Epoch 39, CIFAR-10 Batch 4:  cost: 0.12550747394561768
# Training Accuracy: 1.0
# validation accuracy: 0.625
# Epoch 39, CIFAR-10 Batch 5:  cost: 0.10590733587741852
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6338000297546387
# Epoch 40, CIFAR-10 Batch 1:  cost: 0.17074115574359894
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6191999912261963
# Epoch 40, CIFAR-10 Batch 2:  cost: 0.187132328748703
# Training Accuracy: 0.925000011920929
# validation accuracy: 0.6129999756813049
# Epoch 40, CIFAR-10 Batch 3:  cost: 0.10692425072193146
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6057999730110168
# Epoch 40, CIFAR-10 Batch 4:  cost: 0.09938813745975494
# Training Accuracy: 1.0
# validation accuracy: 0.6266000270843506
# Epoch 40, CIFAR-10 Batch 5:  cost: 0.10716698318719864
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6313999891281128
# Epoch 41, CIFAR-10 Batch 1:  cost: 0.16851767897605896
# Training Accuracy: 1.0
# validation accuracy: 0.6269999742507935
# Epoch 41, CIFAR-10 Batch 2:  cost: 0.15970124304294586
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6233999729156494
# Epoch 41, CIFAR-10 Batch 3:  cost: 0.1035710796713829
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6132000088691711
# Epoch 41, CIFAR-10 Batch 4:  cost: 0.13740453124046326
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6312000155448914
# Epoch 41, CIFAR-10 Batch 5:  cost: 0.10641568899154663
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6291999816894531
# Epoch 42, CIFAR-10 Batch 1:  cost: 0.1835997998714447
# Training Accuracy: 1.0
# validation accuracy: 0.6291999816894531
# Epoch 42, CIFAR-10 Batch 2:  cost: 0.15262040495872498
# Training Accuracy: 1.0
# validation accuracy: 0.6119999885559082
# Epoch 42, CIFAR-10 Batch 3:  cost: 0.10643140971660614
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6047999858856201
# Epoch 42, CIFAR-10 Batch 4:  cost: 0.12817224860191345
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6284000277519226
# Epoch 42, CIFAR-10 Batch 5:  cost: 0.1052832156419754
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6370000243186951
# Epoch 43, CIFAR-10 Batch 1:  cost: 0.1590103656053543
# Training Accuracy: 1.0
# validation accuracy: 0.6276000142097473
# Epoch 43, CIFAR-10 Batch 2:  cost: 0.17878516018390656
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6033999919891357
# Epoch 43, CIFAR-10 Batch 3:  cost: 0.10329705476760864
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.5938000082969666
# Epoch 43, CIFAR-10 Batch 4:  cost: 0.10847151279449463
# Training Accuracy: 1.0
# validation accuracy: 0.6237999796867371
# Epoch 43, CIFAR-10 Batch 5:  cost: 0.11936259269714355
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6276000142097473
# Epoch 44, CIFAR-10 Batch 1:  cost: 0.15212330222129822
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6159999966621399
# Epoch 44, CIFAR-10 Batch 2:  cost: 0.15272563695907593
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6000000238418579
# Epoch 44, CIFAR-10 Batch 3:  cost: 0.09135798364877701
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.5885999798774719
# Epoch 44, CIFAR-10 Batch 4:  cost: 0.09720676392316818
# Training Accuracy: 1.0
# validation accuracy: 0.6244000196456909
# Epoch 44, CIFAR-10 Batch 5:  cost: 0.12804874777793884
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6240000128746033
# Epoch 45, CIFAR-10 Batch 1:  cost: 0.12144754081964493
# Training Accuracy: 1.0
# validation accuracy: 0.623199999332428
# Epoch 45, CIFAR-10 Batch 2:  cost: 0.16010117530822754
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6158000230789185
# Epoch 45, CIFAR-10 Batch 3:  cost: 0.09301581978797913
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6092000007629395
# Epoch 45, CIFAR-10 Batch 4:  cost: 0.11978396028280258
# Training Accuracy: 1.0
# validation accuracy: 0.6269999742507935
# Epoch 45, CIFAR-10 Batch 5:  cost: 0.10686538368463516
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6299999952316284
# Epoch 46, CIFAR-10 Batch 1:  cost: 0.11916114389896393
# Training Accuracy: 1.0
# validation accuracy: 0.6215999722480774
# Epoch 46, CIFAR-10 Batch 2:  cost: 0.15098179876804352
# Training Accuracy: 1.0
# validation accuracy: 0.6033999919891357
# Epoch 46, CIFAR-10 Batch 3:  cost: 0.1223662868142128
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.5996000170707703
# Epoch 46, CIFAR-10 Batch 4:  cost: 0.09081468731164932
# Training Accuracy: 1.0
# validation accuracy: 0.629800021648407
# Epoch 46, CIFAR-10 Batch 5:  cost: 0.10948119312524796
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6227999925613403
# Epoch 47, CIFAR-10 Batch 1:  cost: 0.1260060966014862
# Training Accuracy: 1.0
# validation accuracy: 0.6367999911308289
# Epoch 47, CIFAR-10 Batch 2:  cost: 0.18477480113506317
# Training Accuracy: 1.0
# validation accuracy: 0.614799976348877
# Epoch 47, CIFAR-10 Batch 3:  cost: 0.0839807465672493
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6082000136375427
# Epoch 47, CIFAR-10 Batch 4:  cost: 0.1368047446012497
# Training Accuracy: 1.0
# validation accuracy: 0.6312000155448914
# Epoch 47, CIFAR-10 Batch 5:  cost: 0.11163540184497833
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6205999851226807
# Epoch 48, CIFAR-10 Batch 1:  cost: 0.14048981666564941
# Training Accuracy: 1.0
# validation accuracy: 0.6173999905586243
# Epoch 48, CIFAR-10 Batch 2:  cost: 0.14913494884967804
# Training Accuracy: 1.0
# validation accuracy: 0.6119999885559082
# Epoch 48, CIFAR-10 Batch 3:  cost: 0.10405807197093964
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.5935999751091003
# Epoch 48, CIFAR-10 Batch 4:  cost: 0.09325702488422394
# Training Accuracy: 1.0
# validation accuracy: 0.6230000257492065
# Epoch 48, CIFAR-10 Batch 5:  cost: 0.10568006336688995
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6259999871253967
# Epoch 49, CIFAR-10 Batch 1:  cost: 0.12227834761142731
# Training Accuracy: 1.0
# validation accuracy: 0.6248000264167786
# Epoch 49, CIFAR-10 Batch 2:  cost: 0.16016244888305664
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6155999898910522
# Epoch 49, CIFAR-10 Batch 3:  cost: 0.07347820699214935
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6129999756813049
# Epoch 49, CIFAR-10 Batch 4:  cost: 0.1573602855205536
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6114000082015991
# Epoch 49, CIFAR-10 Batch 5:  cost: 0.10820253193378448
# Training Accuracy: 1.0
# validation accuracy: 0.6294000148773193
# Epoch 50, CIFAR-10 Batch 1:  cost: 0.11887870728969574
# Training Accuracy: 1.0
# validation accuracy: 0.6161999702453613
# Epoch 50, CIFAR-10 Batch 2:  cost: 0.15820828080177307
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.625
# Epoch 50, CIFAR-10 Batch 3:  cost: 0.0947858989238739
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6240000128746033
# Epoch 50, CIFAR-10 Batch 4:  cost: 0.08329936116933823
# Training Accuracy: 1.0
# validation accuracy: 0.6176000237464905
# Epoch 50, CIFAR-10 Batch 5:  cost: 0.08057919144630432
# Training Accuracy: 1.0
# validation accuracy: 0.6205999851226807
# Epoch 51, CIFAR-10 Batch 1:  cost: 0.13086774945259094
# Training Accuracy: 1.0
# validation accuracy: 0.6057999730110168
# Epoch 51, CIFAR-10 Batch 2:  cost: 0.13894984126091003
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6097999811172485
# Epoch 51, CIFAR-10 Batch 3:  cost: 0.09126546233892441
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6287999749183655
# Epoch 51, CIFAR-10 Batch 4:  cost: 0.07353247702121735
# Training Accuracy: 1.0
# validation accuracy: 0.6277999877929688
# Epoch 51, CIFAR-10 Batch 5:  cost: 0.09171909838914871
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6312000155448914
# Epoch 52, CIFAR-10 Batch 1:  cost: 0.1208241730928421
# Training Accuracy: 1.0
# validation accuracy: 0.6176000237464905
# Epoch 52, CIFAR-10 Batch 2:  cost: 0.1332070678472519
# Training Accuracy: 1.0
# validation accuracy: 0.6212000250816345
# Epoch 52, CIFAR-10 Batch 3:  cost: 0.07986734062433243
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6266000270843506
# Epoch 52, CIFAR-10 Batch 4:  cost: 0.056313563138246536
# Training Accuracy: 1.0
# validation accuracy: 0.6245999932289124
# Epoch 52, CIFAR-10 Batch 5:  cost: 0.07514859735965729
# Training Accuracy: 1.0
# validation accuracy: 0.6255999803543091
# Epoch 53, CIFAR-10 Batch 1:  cost: 0.12832801043987274
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.621399998664856
# Epoch 53, CIFAR-10 Batch 2:  cost: 0.17618174850940704
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6159999966621399
# Epoch 53, CIFAR-10 Batch 3:  cost: 0.09162227064371109
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6177999973297119
# Epoch 53, CIFAR-10 Batch 4:  cost: 0.0735408291220665
# Training Accuracy: 1.0
# validation accuracy: 0.6161999702453613
# Epoch 53, CIFAR-10 Batch 5:  cost: 0.07217853516340256
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6226000189781189
# Epoch 54, CIFAR-10 Batch 1:  cost: 0.13616348803043365
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6132000088691711
# Epoch 54, CIFAR-10 Batch 2:  cost: 0.15683309733867645
# Training Accuracy: 1.0
# validation accuracy: 0.6051999926567078
# Epoch 54, CIFAR-10 Batch 3:  cost: 0.08077241480350494
# Training Accuracy: 1.0
# validation accuracy: 0.6320000290870667
# Epoch 54, CIFAR-10 Batch 4:  cost: 0.05378561094403267
# Training Accuracy: 1.0
# validation accuracy: 0.6144000291824341
# Epoch 54, CIFAR-10 Batch 5:  cost: 0.07094224542379379
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6248000264167786
# Epoch 55, CIFAR-10 Batch 1:  cost: 0.11014598608016968
# Training Accuracy: 1.0
# validation accuracy: 0.6204000115394592
# Epoch 55, CIFAR-10 Batch 2:  cost: 0.1353248655796051
# Training Accuracy: 1.0
# validation accuracy: 0.6015999913215637
# Epoch 55, CIFAR-10 Batch 3:  cost: 0.07307952642440796
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6169999837875366
# Epoch 55, CIFAR-10 Batch 4:  cost: 0.05257059261202812
# Training Accuracy: 1.0
# validation accuracy: 0.6205999851226807
# Epoch 55, CIFAR-10 Batch 5:  cost: 0.05095472186803818
# Training Accuracy: 1.0
# validation accuracy: 0.6302000284194946
# Epoch 56, CIFAR-10 Batch 1:  cost: 0.15811923146247864
# Training Accuracy: 0.949999988079071
# validation accuracy: 0.6186000108718872
# Epoch 56, CIFAR-10 Batch 2:  cost: 0.1427687555551529
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6105999946594238
# Epoch 56, CIFAR-10 Batch 3:  cost: 0.05055111646652222
# Training Accuracy: 1.0
# validation accuracy: 0.6245999932289124
# Epoch 56, CIFAR-10 Batch 4:  cost: 0.05257897451519966
# Training Accuracy: 1.0
# validation accuracy: 0.6177999973297119
# Epoch 56, CIFAR-10 Batch 5:  cost: 0.06193579360842705
# Training Accuracy: 1.0
# validation accuracy: 0.6281999945640564
# Epoch 57, CIFAR-10 Batch 1:  cost: 0.1047893762588501
# Training Accuracy: 1.0
# validation accuracy: 0.6176000237464905
# Epoch 57, CIFAR-10 Batch 2:  cost: 0.11804185807704926
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6001999974250793
# Epoch 57, CIFAR-10 Batch 3:  cost: 0.07321969419717789
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6208000183105469
# Epoch 57, CIFAR-10 Batch 4:  cost: 0.03505517914891243
# Training Accuracy: 1.0
# validation accuracy: 0.6105999946594238
# Epoch 57, CIFAR-10 Batch 5:  cost: 0.11699569225311279
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.625
# Epoch 58, CIFAR-10 Batch 1:  cost: 0.07982061058282852
# Training Accuracy: 1.0
# validation accuracy: 0.6195999979972839
# Epoch 58, CIFAR-10 Batch 2:  cost: 0.1266651749610901
# Training Accuracy: 1.0
# validation accuracy: 0.6111999750137329
# Epoch 58, CIFAR-10 Batch 3:  cost: 0.06721748411655426
# Training Accuracy: 1.0
# validation accuracy: 0.6179999709129333
# Epoch 58, CIFAR-10 Batch 4:  cost: 0.08312129974365234
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6205999851226807
# Epoch 58, CIFAR-10 Batch 5:  cost: 0.07436130195856094
# Training Accuracy: 1.0
# validation accuracy: 0.629800021648407
# Epoch 59, CIFAR-10 Batch 1:  cost: 0.13626739382743835
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.621999979019165
# Epoch 59, CIFAR-10 Batch 2:  cost: 0.1237802729010582
# Training Accuracy: 1.0
# validation accuracy: 0.621399998664856
# Epoch 59, CIFAR-10 Batch 3:  cost: 0.06804599612951279
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6222000122070312
# Epoch 59, CIFAR-10 Batch 4:  cost: 0.06408002227544785
# Training Accuracy: 1.0
# validation accuracy: 0.6212000250816345
# Epoch 59, CIFAR-10 Batch 5:  cost: 0.07027089595794678
# Training Accuracy: 1.0
# validation accuracy: 0.6227999925613403
# Epoch 60, CIFAR-10 Batch 1:  cost: 0.12409510463476181
# Training Accuracy: 0.9750000238418579
# validation accuracy: 0.6191999912261963
# Epoch 60, CIFAR-10 Batch 2:  cost: 0.11071624606847763
# Training Accuracy: 1.0
# validation accuracy: 0.6074000000953674
# Epoch 60, CIFAR-10 Batch 3:  cost: 0.06354043632745743
# Training Accuracy: 1.0
# validation accuracy: 0.6241999864578247
# Epoch 60, CIFAR-10 Batch 4:  cost: 0.060314130038022995
# Training Accuracy: 1.0
# validation accuracy: 0.626800000667572
# Epoch 60, CIFAR-10 Batch 5:  cost: 0.0652318000793457
# Training Accuracy: 1.0
# validation accuracy: 0.6284000277519226

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6183742088607594

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
